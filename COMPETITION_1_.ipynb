# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df_info = df.info()
print(df_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 700.0+ bytes
# None

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
animal_age_columns = df[['animal','age']]

# %%
print(animal_age_columns)
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
df.iloc[[3,4,8],[0,1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
select_rows = df[df['visits']>3]
print(select_rows)
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
select_rows = df[df['age'].isna()]
print(select_rows)
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df[(df['animal']=='cat')&(df['age']<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[df['age'].between(2,4,inclusive = 'both')]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc['f','age']=1.5
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
total_visit = df['visits'].sum()
print("THE SUM OF ALL VISITS IS",total_visit)
# Out:
# THE SUM OF ALL VISITS IS 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
mean_age = df.groupby('animal')['age'].mean()
print("mean age for each different animal is",mean_age)
# Out:
# mean age for each different animal is animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
#APPEND A NEW ROW 'k'FORM THE NEW DATAFRAME

# %%
df.loc['k'] = ['rabbit',5,3,'yes']
print("New Dataframe with row 'k' is")
print(df)
# Out:
# New Dataframe with row 'k' is
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c   snake  0.5       2       no
# d     dog  NaN       3      yes
# e     dog  5.0       2       no
# f     cat  1.5       3       no
# g   snake  4.5       1       no
# h     cat  NaN       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no
# k  rabbit  5.0       3      yes

# %%
#delete the new row and return the original dataframe

# %%
df=df.drop('k')
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
animal_counts = df['animal'].value_counts()
print("Total animal count is",animal_counts)
# Out:
# Total animal count is cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
sort_df = df.sort_values(by=['age', 'visits'], ascending=[False, True])
print(sort_df)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].replace({'yes':True,'no':False})
print(df)
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace('snake','python')
print(df)
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  1.5       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
df=pd.read_csv("/content/ny-flights (2) (1).csv")

# %%
df.head()
# Out:
#                 fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0   2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1   2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2   2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3   2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4   2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# 5   2014-01-01 00:00:00             AA       19805   N323AA     185    JFK
# 6   2014-01-01 00:00:00             AA       19805   N328AA     133    JFK
# 7   2014-01-01 00:00:00             AA       19805   N5FJAA     145    JFK
# 8   2014-01-01 00:00:00             AA       19805   N3HYAA     235    JFK
# 9   2014-01-01 00:00:00             AA       19805   N332AA     177    JFK
# 10  2014-01-01 00:00:00             AA       19805   N3JWAA     178    JFK
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
#count the occurance of each airline id

# %%
airline_id_counts = df['airline_id'].value_counts()
print(airline_id__counts)
# Out:
# B6    4902
# DL    3803
# MQ    2434
# AA    2427
# EV    2080
# WN    1917
# US    1568
# UA    1106
# VX     301
# FL     206
# F9      33
# HA      29
# OO      11
# Name: unique_carrier, dtype: int64

# %%
#find the airline id with maximum count
max_airline_id = airline_id_counts.index[0]

# %%
print(max_airline_id)
print("The airline ID which present maximum times in the dataset is",max_airline_id)
# Out:
# 20409
# The airline ID which present maximum times in the dataset is 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['dep_delay'],df['arr_delay'],marker ='^')
plt.title('DEP_DELAY V/S ARR_DELAY')
plt.xlabel('dep_delay')
plt.ylabel('arr_delay')
# Out:
# Text(0, 0.5, 'arr_delay')
